# %% [markdown]
# ### PHS Analysis

# %% [markdown]
# ## Description

# %% [markdown]
# Reading the dataset (Monthly data)
#
# Started the analysis with monthly data dowmloaded from the Public Health Scotland website and reading the dataset

# %%
import pandas as pd

# %%
phs = pd.read_csv('Data/PHS2021.csv')
phs
# Out:
#     Data_Month_Date       Country HB_Treatment_Description  \
# 0        31/12/2021  NHS Scotland     NHS Ayrshire & Arran
# 1        31/12/2021  NHS Scotland     NHS Ayrshire & Arran
# 2        31/12/2021  NHS Scotland     NHS Ayrshire & Arran
# 3        31/12/2021  NHS Scotland     NHS Ayrshire & Arran
# 4        31/12/2021  NHS Scotland     NHS Ayrshire & Arran
# ..              ...           ...                      ...
# 754      31/01/2021  NHS Scotland              NHS Tayside
# 755      31/01/2021  NHS Scotland              NHS Tayside
# 756      31/01/2021  NHS Scotland        NHS Western Isles
# 757      31/01/2021  NHS Scotland        NHS Western Isles
# 758      31/01/2021  NHS Scotland        NHS Western Isles
#
#     Treatment_Location_Code                      Treatment_Location_Name  \
# 0                     A101H                  Arran War Memorial Hospital
# 1                     A110H                       Lady Margaret Hospital
# ...

# %% [markdown]
# **Preview the data**

# %%
phs.head()
# Out:
#   Data_Month_Date       Country HB_Treatment_Description  \
# 0      31/12/2021  NHS Scotland     NHS Ayrshire & Arran
# 1      31/12/2021  NHS Scotland     NHS Ayrshire & Arran
# 2      31/12/2021  NHS Scotland     NHS Ayrshire & Arran
# 3      31/12/2021  NHS Scotland     NHS Ayrshire & Arran
# 4      31/12/2021  NHS Scotland     NHS Ayrshire & Arran
#
#   Treatment_Location_Code              Treatment_Location_Name     ED_MIU  \
# 0                   A101H          Arran War Memorial Hospital  MIU/Other
# 1                   A110H               Lady Margaret Hospital  MIU/Other
# 2                   A111H  University Hospital Crosshouse - ED         ED
# 3                   A210H         University Hospital Ayr - ED         ED
# 4                   A216H            Girvan Community Hospital  MIU/Other
#
#    Number_Of_Attendances_agg  Number_of_Attendances_Epi  \
# 0                        131                        NaN
# 1                         58                        NaN
# ...

# %% [markdown]
# **Checking information about columns, Data types and missing values**

# %%
phs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 759 entries, 0 to 758
# Data columns (total 17 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Data_Month_Date                          759 non-null    object
#  1   Country                                  759 non-null    object
#  2   HB_Treatment_Description                 759 non-null    object
#  3   Treatment_Location_Code                  759 non-null    object
#  4   Treatment_Location_Name                  759 non-null    object
#  5   ED_MIU                                   759 non-null    object
#  6   Number_Of_Attendances_agg                759 non-null    int64
#  7   Number_of_Attendances_Epi                509 non-null    float64
#  8   Number_Meeting_Target_agg                759 non-null    int64
#  9   Number_Meeting_Target_epi                509 non-null    float64
# ...

# %% [markdown]
# ## Weekly Dataset

# %% [markdown]
# The weekly data from the Public Health Scotland site had "percentage_within_4_hours" which is a good measure for performance against the A&E 4 hour standard. I switched to the weekly data instead.

# %% [markdown]
# **Reading the Dataset**

# %%
phs1 = pd.read_csv('Data/PHS_Weekly1.csv')

# %%
phs1
# Out:
#      week_ending_date nhs_board_cypher           nhs_board_name location_code  \
# 0          03/01/2021                A     NHS Ayrshire & Arran         A210H
# 1          03/01/2021                A     NHS Ayrshire & Arran         A111H
# 2          03/01/2021                B              NHS Borders         B120H
# 3          03/01/2021                Y  NHS Dumfries & Galloway         Y146H
# 4          03/01/2021                Y  NHS Dumfries & Galloway         Y144H
# ...               ...              ...                      ...           ...
# 1555       26/12/2021                R               NHS Orkney         R103H
# 1556       26/12/2021                Z             NHS Shetland         Z102H
# 1557       26/12/2021                T              NHS Tayside         T101H
# 1558       26/12/2021                T              NHS Tayside         T202H
# 1559       26/12/2021                W        NHS Western Isles         W107H
#
# ...

# %% [markdown]
# **Preview of the  weekly data**
#
# Head of dataset

# %%
phs1.head()
# Out:
#   week_ending_date nhs_board_cypher           nhs_board_name location_code  \
# 0       03/01/2021                A     NHS Ayrshire & Arran         A210H
# 1       03/01/2021                A     NHS Ayrshire & Arran         A111H
# 2       03/01/2021                B              NHS Borders         B120H
# 3       03/01/2021                Y  NHS Dumfries & Galloway         Y146H
# 4       03/01/2021                Y  NHS Dumfries & Galloway         Y144H
#
#                          location_name  attendance  number_over_4_hours  \
# 0              University Hospital Ayr         456                   89
# 1       University Hospital Crosshouse         885                  249
# 2             Borders General Hospital         477                  108
# 3  Dumfries & Galloway Royal Infirmary         392                   35
# 4          Galloway Community Hospital         151                   25
#
#    percentage_within_4_hours Expressed in %  number_over_8_hours  \
# ...

# %% [markdown]
# **Checking data for missing values and data types**
#
#
# "week_ending_date" has datatype object and needs to be changed to date format

# %%
phs1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   week_ending_date            1560 non-null   object
#  1   nhs_board_cypher            1560 non-null   object
#  2   nhs_board_name              1560 non-null   object
#  3   location_code               1560 non-null   object
#  4   location_name               1560 non-null   object
#  5   attendance                  1560 non-null   int64
#  6   number_over_4_hours         1560 non-null   int64
#  7   percentage_within_4_hours   1560 non-null   float64
#  8   Expressed in %              1560 non-null   object
#  9   number_over_8_hours         1560 non-null   int64
#  10  percentage_within_8_hours   1560 non-null   float64
#  11  number_over_12_hours        1560 non-null   int64
#  12  percentage_within_12_hours  1560 non-null   float64
# ...

# %% [markdown]
# **Converting "week_ending_date" datatype object to date**

# %%
phs1['week_ending_date'] = pd.to_datetime(phs1['week_ending_date'])
phs1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   week_ending_date            1560 non-null   datetime64[ns]
#  1   nhs_board_cypher            1560 non-null   object
#  2   nhs_board_name              1560 non-null   object
#  3   location_code               1560 non-null   object
#  4   location_name               1560 non-null   object
#  5   attendance                  1560 non-null   int64
#  6   number_over_4_hours         1560 non-null   int64
#  7   percentage_within_4_hours   1560 non-null   float64
#  8   Expressed in %              1560 non-null   object
#  9   number_over_8_hours         1560 non-null   int64
#  10  percentage_within_8_hours   1560 non-null   float64
#  11  number_over_12_hours        1560 non-null   int64
#  12  percentage_within_12_hours  1560 non-null   float64
# ...

# %% [markdown]
# **Summary Statistics of the data**

# %%
phs1.describe()
# Out:
#         attendance  number_over_4_hours  percentage_within_4_hours  \
# count  1560.000000          1560.000000                1560.000000
# mean    780.737179           157.089744                  84.786346
# std     550.370127           192.330729                  11.578544
# min      41.000000             0.000000                  41.000000
# 25%     268.750000            15.000000                  77.400000
# 50%     681.000000            92.000000                  87.500000
# 75%    1172.500000           224.000000                  94.000000
# max    2520.000000          1201.000000                 100.000000
#
#        number_over_8_hours  percentage_within_8_hours  number_over_12_hours  \
# count          1560.000000                1560.000000           1560.000000
# mean             28.266667                  97.385192              7.946154
# std              52.020183                   3.673434             21.415099
# ...

# %% [markdown]
# ## VISUALISING THE DATA

# %% [markdown]
# Importing Visualisation package and setting parameters

# %%
import seaborn as sns
sns.set_style('white')
sns.set(rc={'figure.figsize':(10,9)})
from matplotlib import rcParams

# %% [markdown]
# **Data Cloumns**

# %%
phs1.columns
# Out:
# Index(['week_ending_date', 'nhs_board_cypher', 'nhs_board_name',
#        'location_code', 'location_name', 'attendance', 'number_over_4_hours',
#        'percentage_within_4_hours', 'Expressed in %', 'number_over_8_hours',
#        'percentage_within_8_hours', 'number_over_12_hours',
#        'percentage_within_12_hours', 'data_source'],
#       dtype='object')

# %% [markdown]
# ## Investigating Correlation

# %% [markdown]
# **Insight**
#
# Description - There is a significant negative correlation between attendance and percentage_within_4_hours.
#               This correlation will be investigated further.

# %%
phs1_corr = phs1.corr()

phs1_corr
# Out:
#                             attendance  number_over_4_hours  \
# attendance                    1.000000             0.806134
# number_over_4_hours           0.806134             1.000000
# percentage_within_4_hours    -0.601644            -0.869650
# number_over_8_hours           0.578482             0.863483
# percentage_within_8_hours    -0.388789            -0.681576
# number_over_12_hours          0.412589             0.641908
# percentage_within_12_hours   -0.236661            -0.439882
#
#                             percentage_within_4_hours  number_over_8_hours  \
# attendance                                  -0.601644             0.578482
# number_over_4_hours                         -0.869650             0.863483
# percentage_within_4_hours                    1.000000            -0.767647
# number_over_8_hours                         -0.767647             1.000000
# percentage_within_8_hours                    0.804581            -0.868782
# ...

# %% [markdown]
# ## Heatmap of Correlation

# %%
sns.heatmap(phs1_corr, cmap = 'Blues', annot = True,linewidth = 1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Pairplot of Correlation

# %% [markdown]
# **Insight**
#
# Description -  Pair correlation plot details the correleation between varables

# %%
sns.pairplot(phs1, diag_kind = 'kde')

# %% [markdown]
# ## Impact Number of Attendance have on the Performance against A&E 4-hour Standard

# %% [markdown]
# **Insight**
#
# DESCRIPTION -
# There is a negative correlation between percentage within 4-hours and attendance. This means as attendance increases, performance against the 4-hour A&E decreases. Therefore, increase in attendance has a negative impact on performance against A&E 4 hour a standard.

# %%
rg = sns.regplot(x = 'attendance', y = 'percentage_within_4_hours', data = phs1, ci = None, line_kws = {'color':'red'})
rg.set_title('Impact of attendance on the Performance against the A&E Standard')
# Out:
# Text(0.5, 1.0, 'Impact of attendance on the Performance against the A&E Standard')

# %% [markdown]
# ## Performance across NHS Scotland Health Boards

# %% [markdown]
# **Insight**
#
# DESCRIPTION - NHS Orkney, NHS Shetland and NHS Western perform well with percentage within 4 hours above 95%.
# NHS forth valley, NHS Lanarkshire and NHS Borders were trailing at the bottom with performance below 80%.

# %%
bx1  = sns.boxplot(x = 'nhs_board_name', y = 'percentage_within_4_hours', data = phs1, palette = 'coolwarm')
bx1.set_xticklabels(bx1.get_xticklabels(), rotation = 90);
bx1.set_title('Performance against the A&E standard acoss NHS Scotland Health Boards');
# Out:
# Text(0.5, 1.0, 'Performance against the A&E standard acoss NHS Scotland Health Boards')

# %% [markdown]
# ## Performance across NHS Hospitals

# %% [markdown]
# **Insight**
#
# DESCRIPTION - Gilbert Bain Hospital, Royal Aberdeen Children Hospital performed well with percentage_within_4_hours above 95%.
# Royal Infirmary of Edinburgh, University Hospital Wishaw were trailing behind with performance below 70%.

# %%
bx2  = sns.boxplot(y = 'percentage_within_4_hours', x = 'location_name', data = phs1, palette = 'coolwarm')
bx2.set_xticklabels(bx2.get_xticklabels(), rotation = 90);
bx2.set_title('Performance against the A&E standard acoss NHS Scotland Hospitals')
# Out:
# Text(0.5, 1.0, 'Performance against the A&E standard acoss NHS Scotland Hospitals')

# %% [markdown]
# ## Bivariate Histogram plot of attendance across NHS Health Boards

# %% [markdown]
# **Insight**
#
# DESCRIPTION - NHS Orkney, NHS Shetland and NHS Western Isles have very low attendance.
# That could explain why those Health Boards have higher performance against the A&E standard.
# NHS Lothian, NHS Greater glasgow and Clyde has high attendance.

# %%
Bi1 = sns.histplot(x = 'attendance', y = 'nhs_board_name', data = phs1,
            cbar = True,
            )
Bi1.set_title('Bivariate Histogram of attendance and NHS Scotland Health Boards')
# Out:
# Text(0.5, 1.0, 'Bivariate Histogram of attendance and NHS Scotland Health Boards')

# %% [markdown]
# ## Bivariate Histogram plot of attendance across NHS Scotland Hospitals

# %% [markdown]
# **Insight**
#
# DESCRIPTION - Western Isles Hospital, Gilbert Bain Hospital and Balfour Hospital have very low attendance.  NHS Lothian, NHS Royal Infirmary of Edinburgh, Queen Elizabeth University Hospital and Glasgow Royal Infirmary had high attendance.

# %%
Bi2 = sns.histplot(x = 'attendance', y = 'location_name' , data = phs1,
            cbar = True,
            )
Bi2.set_title('Bivariate Histogram of attendance and NHS Scotland Health Boards')
# Out:
# Text(0.5, 1.0, 'Bivariate Histogram of attendance and NHS Scotland Health Boards')

# %% [markdown]
# ## Barplot of performance across NHS Scotland Health Boards

# %% [markdown]
# **Insight**
#
# DESCRIPTION - NHS Orkney, NHS Shetland and NHS Western Isles perform well with percentage within 4 hours above 95%. NHS forth valley, NHS Lanarkshire and NHS Borders were trailing at the bottom with performance below 80%.

# %%
bp = sns.barplot(x='nhs_board_name', y = 'percentage_within_4_hours', data = phs1, ci = None)
sns.set_style('white')
bp.set_xticklabels(bp.get_xticklabels(), rotation = 90);

# %%
phs1.nhs_board_name.value_counts().index[::-1] # Trying to sort Bar plot in ascending order
# Out:
# Index(['NHS Western Isles', 'NHS Shetland', 'NHS Orkney', 'NHS Forth Valley',
#        'NHS Fife', 'NHS Borders', 'NHS Tayside', 'NHS Dumfries & Galloway',
#        'NHS Ayrshire & Arran', 'NHS Lothian', 'NHS Lanarkshire',
#        'NHS Grampian', 'NHS Highland', 'NHS Greater Glasgow & Clyde'],
#       dtype='object')

# %% [markdown]
# ## Barplot of attendance across NHS Scotland Health Boards

# %% [markdown]
# **Insight**
#
# DESCRIPTION - NHS Lothian, NHS Lanarkshire have high attendance.
# NHS Orkney, NHS Shetland and NHS Western Isles have low attendance.

# %%
sns.set_style('white')
bp1 = sns.barplot(x='nhs_board_name', y = 'attendance', data = phs1, ci = None)
bp1.set_xticklabels(bp1.get_xticklabels(), rotation = 90);

# %% [markdown]
# ## Lineplot of Performance against the A&E Standard for the year 2021

# %% [markdown]
# **Insight**
#
# DESCRIPTION - The spikes in the data shows fluctuations in the weekly data for percentage within 4 hours.
# Performance against the A&E 4-hour standard increased in winter 2020/21 but started dropping during spring 2021.
# The drop continued through summer 2021 and autumn 2021. By autumn 2021 performance against the A&E 4-hour standard was below 80% remained at this rate for a prolonged period of time.

# %%
sns.set(rc={'figure.figsize':(15,9)})
Ln1 = sns.lineplot(x = 'week_ending_date', y = 'percentage_within_4_hours', ci  = None, marker = 0, data = phs1)
sns.set_style('white')
Ln1.axhline(82, ls='--', color = 'green')
Ln1.set_xticklabels(Ln1.get_xticklabels(), rotation = 90);
Ln1.set_title('Performance across NHS Scotland throughout the year 2021')
Ln1.set_xticks(range(len(phs1.week_ending_date.unique()))) # <--- set the ticks first
Ln1.set_xticklabels(phs1.week_ending_date.unique());
# Out:
# C:\Users\nhyir\AppData\Local\Temp/ipykernel_23676/3339649713.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   Ln1.set_xticklabels(Ln1.get_xticklabels(), rotation = 90);

# %% [markdown]
# ## Lineplot for attendance across NHS Scotland in 2021

# %% [markdown]
# **Insight**
#
# DESCRIPTION - There was a decrease in attendance in Winter 2020/21 which lasted up to February 2021 probabably due to COVD-19 restrictions but while performance increased in the same period.
# After February 2021, attendance rose sharply in spring 2021 while performance against the A&E 4-hour standard began to fall.
# At the beginning of winter 2021, Total attendance began to fall while performance against the A&E waiting time began to rise.

# %%
sns.set(rc={'figure.figsize':(15,9)})
Ln2 = sns.lineplot(x = 'week_ending_date', y = 'attendance', data = phs1, ci = None)
Ln2.set_title('Attendance in A&E in 2021 across NHS Scotland')
Ln2.axhline(800, ls='--', color = 'green')
Ln2.set_xticklabels(Ln2.get_xticklabels(), rotation = 90);
Ln2.set_xticks(range(len(phs1.week_ending_date.unique()))); # <--- set the ticks first
Ln2.set_xticklabels(phs1.week_ending_date.unique());
# Out:
# C:\Users\nhyir\AppData\Local\Temp/ipykernel_23676/2420586242.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   Ln2.set_xticklabels(Ln2.get_xticklabels(), rotation = 90);

# %% [markdown]
# ## THE END
